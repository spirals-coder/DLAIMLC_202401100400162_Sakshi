# %%
import tensorflow as tf
import numpy as np

#convert data to numpy arrays
x= np.array([1,2,3,4],dtype=float)
y= np.array([2,4,6,8],dtype=float)

#Define model using input layer
model=tf.keras.Sequential([tf.keras.Input(shape=(1,)),
                           tf.keras.layers.Dense(1)])
#compile the model
model.compile(optimizer='sgd',loss='mean_squared_error')

# train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - loss: 24.9488
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 17.3269
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 12.0382
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 8.3684
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 5.8218
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 4.0548
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.8286
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.9776
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.3871
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.9772

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#convert data to numpy arrays
x= np.array([1,2,3,4],dtype=float)
y= np.array([2,4,6,8],dtype=float)

model = Sequential([Dense(1,input_shape=(1,))])

#compile the model
model.compile(optimizer='sgd',loss='mse')

# train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 90.8698
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 63.1091
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 43.8461
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 30.4797
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 21.2046
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 14.7686
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 10.3024
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.2030
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 5.0522
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 3.5594

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#define a single linear model
model = nn.Linear(1,1)

#loss and optimizer
criteria = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

#dummy data
x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

#training loop
for epoch in range(10):
    optimizer.zero_grad()
    outputs=model(x)
    loss=criteria(outputs,y)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 66.08134460449219
# Epoch 2, Loss: 45.884517669677734
# Epoch 3, Loss: 31.87017822265625
# Epoch 4, Loss: 22.145729064941406
# Epoch 5, Loss: 15.397951126098633
# Epoch 6, Loss: 10.715622901916504
# Epoch 7, Loss: 7.46646785736084
# Epoch 8, Loss: 5.211760520935059
# Epoch 9, Loss: 3.647083282470703
# Epoch 10, Loss: 2.561201572418213
